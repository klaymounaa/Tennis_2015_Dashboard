# %% [markdown]
# ## 2015 ATP Matches Analysis

# %% [markdown]
# ### Importing and Reading the dataset

# %% [markdown]
# #### Importing pandas and plotly

# %%
import pandas as pd
import numpy as np 
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Reading raw dataset

# %%
df = pd.read_csv('/Users/klaymouna/Documents/CDSP/projects/final_project/datasets/2000_2017/atp_matches_2015.csv')

# %% [markdown]
# #### Dataframe initial review

# %%
df.shape
# Out:
# (2958, 49)

# %%
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2015-329        Tokyo    Hard         32             A      20151005
# 1   2015-329        Tokyo    Hard         32             A      20151005
# 2   2015-329        Tokyo    Hard         32             A      20151005
# 3   2015-329        Tokyo    Hard         32             A      20151005
# 4   2015-329        Tokyo    Hard         32             A      20151005
#
#    match_num  winner_id  winner_seed winner_entry         winner_name  \
# 0          1     104527          1.0          NaN  Stanislas Wawrinka
# 1          2     105147          NaN           WC         Tatsuma Ito
# 2          3     105572          NaN            Q     Austin Krajicek
# 3          4     105311          NaN          NaN          Joao Sousa
# 4          5     104468          3.0          NaN        Gilles Simon
#
#   winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# ...

# %%
# Info summary: data types + non-null counts
df.info()

# List all column names
print(df.columns.tolist())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2958 entries, 0 to 2957
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          2958 non-null   object
#  1   tourney_name        2958 non-null   object
#  2   surface             2958 non-null   object
#  3   draw_size           2958 non-null   int64
#  4   tourney_level       2958 non-null   object
#  5   tourney_date        2958 non-null   int64
#  6   match_num           2958 non-null   int64
#  7   winner_id           2958 non-null   int64
#  8   winner_seed         1364 non-null   float64
#  9   winner_entry        328 non-null    object
#  10  winner_name         2958 non-null   object
#  11  winner_hand         2953 non-null   object
#  12  winner_ht           2411 non-null   float64
#  13  winner_ioc          2958 non-null   object
#  14  winner_age          2958 non-null   float64
# ...

# %%
# Count missing values per column
missing = df.isnull().sum().sort_values(ascending=False)

# Show top 15 columns with most missing data
missing.head(32)
# Out:
# winner_entry          2630
# loser_entry           2346
# loser_seed            2241
# minutes               1607
# winner_seed           1594
# loser_ht               797
# winner_ht              547
# w_ace                  333
# w_df                   333
# w_svpt                 333
# w_1stIn                333
# w_1stWon               333
# w_2ndWon               333
# w_SvGms                333
# w_bpSaved              333
# l_bpFaced              333
# w_bpFaced              333
# l_ace                  333
# l_df                   333
# l_svpt                 333
# l_1stIn                333
# l_1stWon               333
# l_2ndWon               333
# l_SvGms                333
# l_bpSaved              333
# loser_rank              50
# loser_rank_points       50
# winner_rank_points      27
# winner_rank             27
# loser_hand               6
# winner_hand              5
# loser_age                4
# dtype: int64

# %%
fig = px.bar(
    x=missing.index, 
    y=missing.values,
    title="Missing Values per Column",
    labels={"x":"Column", "y":"Missing Count"}
)
fig.update_layout(xaxis_tickangle=45)
fig.show()

# %%
# Summary for numeric columns
df.describe()
# Out:
#          draw_size  tourney_date    match_num      winner_id  winner_seed  \
# count  2958.000000  2.958000e+03  2958.000000    2958.000000  1364.000000
# mean     52.098715  2.015057e+07    26.137255  105303.635565     7.251466
# std      40.258965  2.937136e+02    27.461919    4448.132712     6.774577
# min       4.000000  2.015010e+07     1.000000  100644.000000     1.000000
# 25%      28.000000  2.015031e+07     7.000000  104527.000000     2.000000
# 50%      32.000000  2.015052e+07    18.000000  104918.000000     5.000000
# 75%      56.000000  2.015082e+07    31.000000  105453.000000     8.000000
# max     128.000000  2.015113e+07   127.000000  200537.000000    32.000000
#
#         winner_ht   winner_age  winner_rank  winner_rank_points  \
# count  2411.00000  2958.000000  2931.000000         2931.000000
# mean    187.17752    27.879325    74.882975         2094.142272
# std       7.88233     3.837611   151.635551         2774.034435
# ...

# %%
# Summary for categorical columns
df.describe(include=['object'])
# Out:
#        tourney_id     tourney_name surface tourney_level winner_entry  \
# count        2958             2958    2958          2958          328
# unique        148              148       3             6            4
# top      2015-580  Australian Open    Hard             A            Q
# freq          127              127    1702          1540          181
#
#            winner_name winner_hand winner_ioc loser_entry  loser_name  \
# count             2958        2953       2958         612        2958
# unique             287           3         73           5         404
# top     Novak Djokovic           R        ESP           Q  Joao Sousa
# freq                83        2444        380         345          31
#
#        loser_hand loser_ioc    score round
# count        2952      2958     2958  2958
# unique          3        78     1338     8
# top             R       ESP  6-3 6-4   R32
# freq         2342       315       99   904

# %%
fig = px.histogram(df, x="surface", title="Distribution of Court Surfaces")
fig.show()

# %%
fig = px.histogram(df, x="tourney_level", title="Tournament Levels (ATP, Grand Slam, etc.)")
fig.show()

# %%
# How many unique tournaments and players
print("Unique tournaments:", df["tourney_name"].nunique())
print("Unique winners:", df["winner_id"].nunique())
print("Unique losers:", df["loser_id"].nunique())
# Out:
# Unique tournaments: 148
# Unique winners: 287
# Unique losers: 404

# %% [markdown]
# ### Cleaning the Dataset

# %% [markdown]
# #### Filling NAN

# %% [markdown]
# ##### Checking nan status

# %%
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2015-329        Tokyo    Hard         32             A      20151005
# 1   2015-329        Tokyo    Hard         32             A      20151005
# 2   2015-329        Tokyo    Hard         32             A      20151005
# 3   2015-329        Tokyo    Hard         32             A      20151005
# 4   2015-329        Tokyo    Hard         32             A      20151005
#
#    match_num  winner_id  winner_seed winner_entry         winner_name  \
# 0          1     104527          1.0          NaN  Stanislas Wawrinka
# 1          2     105147          NaN           WC         Tatsuma Ito
# 2          3     105572          NaN            Q     Austin Krajicek
# 3          4     105311          NaN          NaN          Joao Sousa
# 4          5     104468          3.0          NaN        Gilles Simon
#
#   winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# ...

# %%
missing = df.isnull().sum().sort_values(ascending=False)
missing = missing[missing > 0]  # only show columns with missing values
print("Columns with missing values (count):\n")
print(missing)
# Out:
# Columns with missing values (count):
#
# winner_entry          2630
# loser_entry           2346
# loser_seed            2241
# minutes               1607
# winner_seed           1594
# loser_ht               797
# winner_ht              547
# w_ace                  333
# w_df                   333
# w_svpt                 333
# w_1stIn                333
# w_1stWon               333
# w_2ndWon               333
# w_SvGms                333
# w_bpSaved              333
# l_bpFaced              333
# w_bpFaced              333
# l_ace                  333
# l_df                   333
# l_svpt                 333
# l_1stIn                333
# l_1stWon               333
# l_2ndWon               333
# l_SvGms                333
# l_bpSaved              333
# loser_rank              50
# loser_rank_points       50
# winner_rank_points      27
# winner_rank             27
# loser_hand               6
# winner_hand              5
# loser_age                4
# dtype: int64

# %% [markdown]
# ##### Remove rows where tourney_name == 'Challenger Tour Finals' or tourney_name starts with 'Davis Cup'

# %%
# remove rows where tourney_name == 'Challenger Tour Finals' or tourney_name starts with 'Davis Cup'

df = df[~(
    (df['tourney_name'] == 'Challenger Tour Finals') |
    (df['tourney_name'].str.startswith('Davis Cup', na=False))
)]

# %% [markdown]
# ##### Will change nan in winner_entry to D as Direct join

# %%
df['winner_entry'].unique()
# Out:
# array([nan, 'WC', 'Q', 'LL', 'PR'], dtype=object)

# %%
df['winner_entry'] = df['winner_entry'].fillna('D')

# %%
df['winner_entry'].unique()
# Out:
# array(['D', 'WC', 'Q', 'LL', 'PR'], dtype=object)

# %% [markdown]
# ##### Will change nan in loser_entry to D as Direct join

# %%
# will change nan in loser_entry to D as Direct join
df['loser_entry'] = df['loser_entry'].fillna('D')

# %%
df['loser_entry'].unique()
# Out:
# array(['PR', 'WC', 'Q', 'D', 'LL', 'S'], dtype=object)

# %% [markdown]
# ##### Seed = a player’s ranking position inside a tournament’s draw.
# ##### Change nan in winner_seed to 0 meaning unseeded player

# %%
df['winner_seed'].unique()
# Out:
# array([ 1., nan,  3.,  6.,  2.,  5.,  8.,  7.,  4., 13., 12., 16., 15.,
#        11., 10.,  9., 14., 27., 24., 17., 32., 21., 26., 30., 22., 23.,
#        25., 18., 20., 28., 31., 29., 19.])

# %%
df['winner_seed'] = df['winner_seed'].fillna(0)

# %%
df['winner_seed'].unique()
# Out:
# array([ 1.,  0.,  3.,  6.,  2.,  5.,  8.,  7.,  4., 13., 12., 16., 15.,
#        11., 10.,  9., 14., 27., 24., 17., 32., 21., 26., 30., 22., 23.,
#        25., 18., 20., 28., 31., 29., 19.])

# %% [markdown]
# ##### Change nan in loser_seed to 0 meaning unseeded player

# %%
df['loser_seed'].unique()
# Out:
# array([nan,  7.,  5.,  8.,  4.,  3.,  6.,  2.,  1., 10., 14., 11.,  9.,
#        13., 16., 15., 12., 28., 19., 29., 31., 32., 30., 27., 24., 17.,
#        25., 18., 26., 22., 23., 20., 21., 33.])

# %%
df['loser_seed'] = df['loser_seed'].fillna(0)

# %%
df['loser_seed'].unique()
# Out:
# array([ 0.,  7.,  5.,  8.,  4.,  3.,  6.,  2.,  1., 10., 14., 11.,  9.,
#        13., 16., 15., 12., 28., 19., 29., 31., 32., 30., 27., 24., 17.,
#        25., 18., 26., 22., 23., 20., 21., 33.])

# %% [markdown]
# ##### Cleaning winner_ht and loser_ht using median heights of the data

# %%
# calculate medians
winner_ht_median = df['winner_ht'].median()
loser_ht_median = df['loser_ht'].median()

# fill NaN values with the median
df['winner_ht'] = df['winner_ht'].fillna(winner_ht_median)
df['loser_ht']  = df['loser_ht'].fillna(loser_ht_median)

# %%
missing = df.isnull().sum().sort_values(ascending=False)
missing = missing[missing > 0]  # only show columns with missing values
print("Columns with missing values (count):\n")
print(missing)
# Out:
# Columns with missing values (count):
#
# minutes               1279
# loser_rank_points        6
# loser_rank               6
# w_ace                    5
# w_df                     5
# w_svpt                   5
# w_1stIn                  5
# w_1stWon                 5
# w_2ndWon                 5
# w_SvGms                  5
# l_bpFaced                5
# w_bpFaced                5
# l_ace                    5
# l_df                     5
# l_svpt                   5
# l_1stIn                  5
# l_1stWon                 5
# l_2ndWon                 5
# l_SvGms                  5
# l_bpSaved                5
# w_bpSaved                5
# winner_rank              3
# winner_rank_points       3
# loser_age                1
# dtype: int64

# %%
df['best_of'].unique()
# Out:
# array([3, 5])

# %% [markdown]
# ##### Cleaning minutes according to set median time

# %%
df['best_of'].unique()
# Out:
# array([3, 5])

# %%
# step1: creates num_sets column
df['sets_num'] = df['score'].astype(str).str.strip().str.split().str.len()

# %%
df[['score', 'sets_num']].head(20)
# Out:
#                 score  sets_num
# 0             7-5 6-3         2
# 1         3-6 6-0 7-5         3
# 2   5-7 7-6(4) 7-6(5)         3
# 3         6-4 4-6 6-1         3
# 4             6-4 6-4         2
# 5             6-4 6-4         2
# 6         6-3 2-0 RET         3
# 7             6-2 6-3         2
# 8         6-4 3-6 6-1         3
# 9             7-5 6-1         2
# 10     6-7(3) 6-3 6-3         3
# 11            6-4 6-1         2
# 12        7-5 5-7 6-4         3
# 13        6-3 2-1 RET         3
# 14         7-6(5) 6-4         2
# 15        2-6 6-1 6-2         3
# 16        6-3 2-6 6-4         3
# 17        2-6 6-4 6-3         3
# 18            6-4 6-2         2
# 19      7-6(3) 7-6(5)         2

# %%
# step1 (without RET) remove trailing "RET" before counting sets
df['sets_num'] = (
    df['score']
    .astype(str)
    .str.replace(r'\s*RET$', '', regex=True)  # remove "RET" at end
    .str.strip()
    .str.split()
    .str.len()
)

# %%
df[['score', 'sets_num']].head(20)
# Out:
#                 score  sets_num
# 0             7-5 6-3         2
# 1         3-6 6-0 7-5         3
# 2   5-7 7-6(4) 7-6(5)         3
# 3         6-4 4-6 6-1         3
# 4             6-4 6-4         2
# 5             6-4 6-4         2
# 6         6-3 2-0 RET         2
# 7             6-2 6-3         2
# 8         6-4 3-6 6-1         3
# 9             7-5 6-1         2
# 10     6-7(3) 6-3 6-3         3
# 11            6-4 6-1         2
# 12        7-5 5-7 6-4         3
# 13        6-3 2-1 RET         2
# 14         7-6(5) 6-4         2
# 15        2-6 6-1 6-2         3
# 16        6-3 2-6 6-4         3
# 17        2-6 6-4 6-3         3
# 18            6-4 6-2         2
# 19      7-6(3) 7-6(5)         2

# %%
# Step 2: Create minutes_per_set column
df['minutes_per_set'] = df['minutes'] / df['sets_num']

# %%
# Step 3: Fill NA in 'minutes' using the median of minutes_per_set
median_mins_per_set = df['minutes_per_set'].median()

# Fill missing 'minutes' using estimated value = median * sets_num
df['minutes'] = df['minutes'].fillna(df['sets_num'] * median_mins_per_set)

# %%
# drpo 'minutes_per_set' column
df = df.drop(columns=['minutes_per_set'])

# %% [markdown]
# ##### Change winner_rank and loser_rank nans to 0 (as all their seeds are 0)

# %%
df[df['winner_rank'].isna()]
# Out:
#      tourney_id         tourney_name surface  draw_size tourney_level  \
# 2017   2015-410  Monte Carlo Masters    Clay         56             M
# 2216   2015-717              Houston    Clay         28             A
# 2315   2015-321            Stuttgart   Grass         28             A
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  \
# 2017      20150412          6     104252          0.0            D
# 2216      20150406         11     104386          0.0           WC
# 2315      20150608          2     103163          0.0           WC
#
#            winner_name winner_hand  winner_ht winner_ioc  winner_age  \
# 2017     Florian Mayer           R      190.0        GER   31.520876
# 2216  Janko Tipsarevic           R      180.0        SRB   30.787132
# 2315        Tommy Haas           R      188.0        GER   37.180014
#
#       winner_rank  winner_rank_points  loser_id  loser_seed loser_entry  \
# ...

# %%
df[df['loser_rank'].isna()]
# Out:
#      tourney_id          tourney_name surface  draw_size tourney_level  \
# 652    2015-404  Indian Wells Masters    Hard         96             M
# 1817  2015-6116               Atlanta    Hard         28             A
# 2039   2015-410   Monte Carlo Masters    Clay         56             M
# 2095   2015-451                  Doha    Hard         32             A
# 2224   2015-717               Houston    Clay         28             A
# 2327   2015-321             Stuttgart   Grass         28             A
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  \
# 652       20150312         16     105992          0.0           WC
# 1817      20150727          1     103285          0.0           PR
# 2039      20150412         28     105227          8.0            D
# 2095      20150105          2     104660          0.0            D
# 2224      20150406         19     105053          5.0            D
# ...

# %%
df['winner_rank'] = df['winner_rank'].fillna(0)
df['loser_rank']  = df['loser_rank'].fillna(0)

# %% [markdown]
# ##### Checking remaining nans

# %%
# Show all rows with any missing values
df[df.isna().any(axis=1)]
# Out:
#      tourney_id          tourney_name surface  draw_size tourney_level  \
# 652    2015-404  Indian Wells Masters    Hard         96             M
# 725    2015-404  Indian Wells Masters    Hard         96             M
# 1817  2015-6116               Atlanta    Hard         28             A
# 1820  2015-6116               Atlanta    Hard         28             A
# 1972   2015-416          Rome Masters    Clay         56             M
# 2017   2015-410   Monte Carlo Masters    Clay         56             M
# 2039   2015-410   Monte Carlo Masters    Clay         56             M
# 2095   2015-451                  Doha    Hard         32             A
# 2216   2015-717               Houston    Clay         28             A
# 2224   2015-717               Houston    Clay         28             A
# 2315   2015-321             Stuttgart   Grass         28             A
# 2327   2015-321             Stuttgart   Grass         28             A
# ...

# %%
missing = df.isnull().sum().sort_values(ascending=False)
missing = missing[missing > 0]  # only show columns with missing values
print("Columns with missing values (count):\n")
print(missing)
# Out:
# Columns with missing values (count):
#
# loser_rank_points     6
# w_SvGms               5
# l_ace                 5
# w_ace                 5
# w_df                  5
# w_svpt                5
# w_1stIn               5
# w_1stWon              5
# w_2ndWon              5
# w_bpSaved             5
# w_bpFaced             5
# l_df                  5
# l_svpt                5
# l_1stIn               5
# l_1stWon              5
# l_2ndWon              5
# l_SvGms               5
# l_bpSaved             5
# l_bpFaced             5
# winner_rank_points    3
# loser_age             1
# dtype: int64

# %%
df[df['loser_age'].isna()]
# Out:
#      tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 1817  2015-6116      Atlanta    Hard         28             A      20150727
#
#       match_num  winner_id  winner_seed winner_entry     winner_name  \
# 1817          1     103285          0.0           PR  Radek Stepanek
#
#      winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# 1817           R      185.0        CZE    36.66256        290.0
#
#       winner_rank_points  loser_id  loser_seed loser_entry  \
# 1817               162.0    111153         0.0          WC
#
#                loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# 1817  Christopher Eubanks          U     188.0       USA        NaN
#
#       loser_rank  loser_rank_points    score  best_of round  minutes  w_ace  \
# 1817         0.0                NaN  6-2 6-2        3   R32     80.0    0.0
#
#       w_df  w_svpt  w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  \
# ...

# %%
df[df['loser_name'] == 'Christopher Eubanks']
# Out:
#      tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 1817  2015-6116      Atlanta    Hard         28             A      20150727
#
#       match_num  winner_id  winner_seed winner_entry     winner_name  \
# 1817          1     103285          0.0           PR  Radek Stepanek
#
#      winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# 1817           R      185.0        CZE    36.66256        290.0
#
#       winner_rank_points  loser_id  loser_seed loser_entry  \
# 1817               162.0    111153         0.0          WC
#
#                loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# 1817  Christopher Eubanks          U     188.0       USA        NaN
#
#       loser_rank  loser_rank_points    score  best_of round  minutes  w_ace  \
# 1817         0.0                NaN  6-2 6-2        3   R32     80.0    0.0
#
#       w_df  w_svpt  w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  \
# ...

# %% [markdown]
# ##### Change winner_rank and loser_rank nans to 0 (as all their seeds are 0)

# %%
df[df['winner_rank_points'].isna()]
# Out:
#      tourney_id         tourney_name surface  draw_size tourney_level  \
# 2017   2015-410  Monte Carlo Masters    Clay         56             M
# 2216   2015-717              Houston    Clay         28             A
# 2315   2015-321            Stuttgart   Grass         28             A
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  \
# 2017      20150412          6     104252          0.0            D
# 2216      20150406         11     104386          0.0           WC
# 2315      20150608          2     103163          0.0           WC
#
#            winner_name winner_hand  winner_ht winner_ioc  winner_age  \
# 2017     Florian Mayer           R      190.0        GER   31.520876
# 2216  Janko Tipsarevic           R      180.0        SRB   30.787132
# 2315        Tommy Haas           R      188.0        GER   37.180014
#
#       winner_rank  winner_rank_points  loser_id  loser_seed loser_entry  \
# ...

# %%
df[df['loser_rank_points'].isna()]
# Out:
#      tourney_id          tourney_name surface  draw_size tourney_level  \
# 652    2015-404  Indian Wells Masters    Hard         96             M
# 1817  2015-6116               Atlanta    Hard         28             A
# 2039   2015-410   Monte Carlo Masters    Clay         56             M
# 2095   2015-451                  Doha    Hard         32             A
# 2224   2015-717               Houston    Clay         28             A
# 2327   2015-321             Stuttgart   Grass         28             A
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  \
# 652       20150312         16     105992          0.0           WC
# 1817      20150727          1     103285          0.0           PR
# 2039      20150412         28     105227          8.0            D
# 2095      20150105          2     104660          0.0            D
# 2224      20150406         19     105053          5.0            D
# ...

# %%
df['winner_rank_points'] = df['winner_rank_points'].fillna(0)
df['loser_rank_points']  = df['loser_rank_points'].fillna(0)

# %% [markdown]
# ##### Checking remaining nans

# %%
# Show all rows with any missing values
df[df.isna().any(axis=1)]
# Out:
#      tourney_id          tourney_name surface  draw_size tourney_level  \
# 725    2015-404  Indian Wells Masters    Hard         96             M
# 1817  2015-6116               Atlanta    Hard         28             A
# 1820  2015-6116               Atlanta    Hard         28             A
# 1972   2015-416          Rome Masters    Clay         56             M
# 2561   2015-520         Roland Garros    Clay        128             G
# 2592   2015-520         Roland Garros    Clay        128             G
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  \
# 725       20150312         89     104925          1.0            D
# 1817      20150727          1     103285          0.0           PR
# 1820      20150727          4     106045          0.0            Q
# 1972      20150510         43     105676          0.0            D
# 2561      20150524         74     106401         29.0            D
# ...

# %% [markdown]
# ##### Fill nan in loser_age with median loser_age

# %%
median_loser_age = df['loser_age'].median()
df['loser_age'] = df['loser_age'].fillna(median_loser_age)

# %% [markdown]
# ##### Fill missing w_ and l_ statistics with median of their values

# %%
# Identify all columns that start with w_ or l_
cols_to_fill = [col for col in df.columns if col.startswith('w_') or col.startswith('l_')]
cols_to_fill
# Out:
# ['w_ace',
#  'w_df',
#  'w_svpt',
#  'w_1stIn',
#  'w_1stWon',
#  'w_2ndWon',
#  'w_SvGms',
#  'w_bpSaved',
#  'w_bpFaced',
#  'l_ace',
#  'l_df',
#  'l_svpt',
#  'l_1stIn',
#  'l_1stWon',
#  'l_2ndWon',
#  'l_SvGms',
#  'l_bpSaved',
#  'l_bpFaced']

# %%
# Fill their missing values with each column's own median
df[cols_to_fill] = df[cols_to_fill].fillna(df[cols_to_fill].median())

# %% [markdown]
# ##### Checking remaining nans

# %%
# Show all rows with any missing values
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [tourney_id, tourney_name, surface, draw_size, tourney_level, tourney_date, match_num, winner_id, winner_seed, winner_entry, winner_name, winner_hand, winner_ht, winner_ioc, winner_age, winner_rank, winner_rank_points, loser_id, loser_seed, loser_entry, loser_name, loser_hand, loser_ht, loser_ioc, loser_age, loser_rank, loser_rank_points, score, best_of, round, minutes, w_ace, w_df, w_svpt, w_1stIn, w_1stWon, w_2ndWon, w_SvGms, w_bpSaved, w_bpFaced, l_ace, l_df, l_svpt, l_1stIn, l_1stWon, l_2ndWon, l_SvGms, l_bpSaved, l_bpFaced, sets_num]
# Index: []

# %% [markdown]
# #### Cleaning Data

# %% [markdown]
# ##### data updated overview

# %%
df.shape
# Out:
# (2630, 50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2630 entries, 0 to 2629
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          2630 non-null   object
#  1   tourney_name        2630 non-null   object
#  2   surface             2630 non-null   object
#  3   draw_size           2630 non-null   int64
#  4   tourney_level       2630 non-null   object
#  5   tourney_date        2630 non-null   int64
#  6   match_num           2630 non-null   int64
#  7   winner_id           2630 non-null   int64
#  8   winner_seed         2630 non-null   float64
#  9   winner_entry        2630 non-null   object
#  10  winner_name         2630 non-null   object
#  11  winner_hand         2630 non-null   object
#  12  winner_ht           2630 non-null   float64
#  13  winner_ioc          2630 non-null   object
#  14  winner_age          2630 non-null   float64
# ...

# %%
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2015-329        Tokyo    Hard         32             A      20151005
# 1   2015-329        Tokyo    Hard         32             A      20151005
# 2   2015-329        Tokyo    Hard         32             A      20151005
# 3   2015-329        Tokyo    Hard         32             A      20151005
# 4   2015-329        Tokyo    Hard         32             A      20151005
#
#    match_num  winner_id  winner_seed winner_entry         winner_name  \
# 0          1     104527          1.0            D  Stanislas Wawrinka
# 1          2     105147          0.0           WC         Tatsuma Ito
# 2          3     105572          0.0            Q     Austin Krajicek
# 3          4     105311          0.0            D          Joao Sousa
# 4          5     104468          3.0            D        Gilles Simon
#
#   winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# ...

# %% [markdown]
# ##### stripping all non-numeric columns data

# %%
df = df.apply(lambda col: col.str.strip() if col.dtype == "object" else col)

# %% [markdown]
# ##### changing tourney_date type to data

# %%
df['tourney_date'] = pd.to_datetime(df['tourney_date'].astype(str), format='%Y%m%d')

# %%
df.head(2)
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0   2015-329        Tokyo    Hard         32             A   2015-10-05
# 1   2015-329        Tokyo    Hard         32             A   2015-10-05
#
#    match_num  winner_id  winner_seed winner_entry         winner_name  \
# 0          1     104527          1.0            D  Stanislas Wawrinka
# 1          2     105147          0.0           WC         Tatsuma Ito
#
#   winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# 0           R      183.0        SUI   30.521561          4.0
# 1           R      180.0        JPN   27.381246        127.0
#
#    winner_rank_points  loser_id  loser_seed loser_entry          loser_name  \
# 0              6005.0    103285         0.0          PR      Radek Stepanek
# 1               444.0    106415         0.0          WC  Yoshihito Nishioka
#
#   loser_hand  loser_ht loser_ioc  loser_age  loser_rank  loser_rank_points  \
# ...

# %% [markdown]
# ##### arranging df to dates and tourney_name

# %%
df = df.sort_values(
    by=['tourney_date', 'tourney_name'],
    ascending=[True, True]
).reset_index(drop=True)

# %%
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0   2015-339     Brisbane    Hard         28             A   2015-01-04
# 1   2015-339     Brisbane    Hard         28             A   2015-01-04
# 2   2015-339     Brisbane    Hard         28             A   2015-01-04
# 3   2015-339     Brisbane    Hard         28             A   2015-01-04
# 4   2015-339     Brisbane    Hard         28             A   2015-01-04
#
#    match_num  winner_id  winner_seed winner_entry      winner_name  \
# 0          1     105357          0.0           WC     John Millman
# 1          2     103813          0.0            D  Jarkko Nieminen
# 2          3     105902          0.0           WC  James Duckworth
# 3          4     104871          0.0            D    Jeremy Chardy
# 4          5     105373          0.0            D    Martin Klizan
#
#   winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# 0           R      183.0        AUS   25.560575        153.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          2630 non-null   object
#  1   tourney_name        2630 non-null   object
#  2   surface             2630 non-null   object
#  3   draw_size           2630 non-null   int64
#  4   tourney_level       2630 non-null   object
#  5   tourney_date        2630 non-null   datetime64[ns]
#  6   match_num           2630 non-null   int64
#  7   winner_id           2630 non-null   int64
#  8   winner_seed         2630 non-null   float64
#  9   winner_entry        2630 non-null   object
#  10  winner_name         2630 non-null   object
#  11  winner_hand         2630 non-null   object
#  12  winner_ht           2630 non-null   float64
#  13  winner_ioc          2630 non-null   object
#  14  winner_age          2630 non-null   float64
# ...

# %% [markdown]
# ##### int any numeric columns except (winner_age, loser_age)

# %%
numeric_cols = df.select_dtypes(include=['number']).columns.tolist()
numeric_cols
# Out:
# ['draw_size',
#  'match_num',
#  'winner_id',
#  'winner_seed',
#  'winner_ht',
#  'winner_age',
#  'winner_rank',
#  'winner_rank_points',
#  'loser_id',
#  'loser_seed',
#  'loser_ht',
#  'loser_age',
#  'loser_rank',
#  'loser_rank_points',
#  'best_of',
#  'minutes',
#  'w_ace',
#  'w_df',
#  'w_svpt',
#  'w_1stIn',
#  'w_1stWon',
#  'w_2ndWon',
#  'w_SvGms',
#  'w_bpSaved',
#  'w_bpFaced',
#  'l_ace',
#  'l_df',
#  'l_svpt',
#  'l_1stIn',
#  'l_1stWon',
#  'l_2ndWon',
#  'l_SvGms',
#  'l_bpSaved',
#  'l_bpFaced',
#  'sets_num']

# %%
cols_to_int = [col for col in numeric_cols if col not in ['winner_age', 'loser_age']]
cols_to_int
# Out:
# ['draw_size',
#  'match_num',
#  'winner_id',
#  'winner_seed',
#  'winner_ht',
#  'winner_rank',
#  'winner_rank_points',
#  'loser_id',
#  'loser_seed',
#  'loser_ht',
#  'loser_rank',
#  'loser_rank_points',
#  'best_of',
#  'minutes',
#  'w_ace',
#  'w_df',
#  'w_svpt',
#  'w_1stIn',
#  'w_1stWon',
#  'w_2ndWon',
#  'w_SvGms',
#  'w_bpSaved',
#  'w_bpFaced',
#  'l_ace',
#  'l_df',
#  'l_svpt',
#  'l_1stIn',
#  'l_1stWon',
#  'l_2ndWon',
#  'l_SvGms',
#  'l_bpSaved',
#  'l_bpFaced',
#  'sets_num']

# %%
df[cols_to_int] = df[cols_to_int].astype('Int64')   # nullable integer type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          2630 non-null   object
#  1   tourney_name        2630 non-null   object
#  2   surface             2630 non-null   object
#  3   draw_size           2630 non-null   Int64
#  4   tourney_level       2630 non-null   object
#  5   tourney_date        2630 non-null   datetime64[ns]
#  6   match_num           2630 non-null   Int64
#  7   winner_id           2630 non-null   Int64
#  8   winner_seed         2630 non-null   Int64
#  9   winner_entry        2630 non-null   object
#  10  winner_name         2630 non-null   object
#  11  winner_hand         2630 non-null   object
#  12  winner_ht           2630 non-null   Int64
#  13  winner_ioc          2630 non-null   object
#  14  winner_age          2630 non-null   float64
# ...

# %% [markdown]
# ##### round winner_age, loser_age to 2 decimals

# %%
df['winner_age'] = df['winner_age'].round(1)
df['loser_age']   = df['loser_age'].round()

# %%
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0   2015-339     Brisbane    Hard         28             A   2015-01-04
# 1   2015-339     Brisbane    Hard         28             A   2015-01-04
# 2   2015-339     Brisbane    Hard         28             A   2015-01-04
# 3   2015-339     Brisbane    Hard         28             A   2015-01-04
# 4   2015-339     Brisbane    Hard         28             A   2015-01-04
#
#    match_num  winner_id  winner_seed winner_entry      winner_name  \
# 0          1     105357            0           WC     John Millman
# 1          2     103813            0            D  Jarkko Nieminen
# 2          3     105902            0           WC  James Duckworth
# 3          4     104871            0            D    Jeremy Chardy
# 4          5     105373            0            D    Martin Klizan
#
#   winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# 0           R        183        AUS        25.6          153
# ...

# %% [markdown]
# ##### U in winner_hand, loser_hand (Undetermined hand) will keep as is

# %%
players_with_U = pd.unique(
    pd.concat([
        df.loc[df['winner_hand'] == 'U', 'winner_name'],
        df.loc[df['loser_hand']  == 'U', 'loser_name']
    ])
)

players_with_U
# Out:
# array(['Luca Vanni', 'Hyeon Chung', 'Nikola Mektic', 'Taylor Harry Fritz',
#        'Christian Lindell', 'Daniel Elahi Galan Riveros',
#        'Alejandro Gomez GB42', 'Bastian Trinker', 'Jaume Munar',
#        'Radu Albot', 'Zhizhen Zhang', 'Yan Bai', 'Aslan Karatsev',
#        'N Vijay Sundar Prashanth', 'Jabor Al Mutawa', 'Laurent Lokoli',
#        'Marton Fucsovics', 'Toni Androic', 'Eric Quigley',
#        'Yassine Idmbarek', 'Thomas Fabbiano', 'Lorenzo Giustino',
#        'Federico Gaio', 'Germain Gigounon', 'Ante Pavic',
#        'Markus Eriksson', 'Matteo Trevisan', 'Christopher Eubanks',
#        'Darian King', 'Tommy Paul', 'Ryan Shane', 'Yaraslau Shyla',
#        'Takuto Niki'], dtype=object)

# %%
df[df['winner_hand'] == 'U']
# Out:
#      tourney_id    tourney_name surface  draw_size tourney_level tourney_date  \
# 417    2015-533       Sao Paulo    Clay         28             A   2015-02-09
# 425    2015-533       Sao Paulo    Clay         28             A   2015-02-09
# 429    2015-533       Sao Paulo    Clay         28             A   2015-02-09
# 729    2015-403   Miami Masters    Hard         96             M   2015-03-25
# 831    2015-717         Houston    Clay         28             A   2015-04-06
# 957    2015-773       Bucharest    Clay         28             A   2015-04-20
# 1071  2015-1536  Madrid Masters    Clay         56             M   2015-05-03
# 1475   2015-741      Nottingham   Grass         48             A   2015-06-21
# 1482   2015-741      Nottingham   Grass         48             A   2015-06-21
# 1683   2015-316          Bastad    Clay         28             A   2015-07-20
# 1703  2015-6718          Bogota    Hard         28             A   2015-07-20
# ...

# %%
df[df['loser_hand'] == 'U']
# Out:
#      tourney_id      tourney_name surface  draw_size tourney_level  \
# 30     2015-891           Chennai    Hard         28             A
# 31     2015-891           Chennai    Hard         28             A
# 55     2015-451              Doha    Hard         32             A
# 144    2015-580   Australian Open    Hard        128             G
# 272    2015-375       Montpellier    Hard         28             A
# 295   2015-7161             Quito    Clay         28             A
# 301   2015-7161             Quito    Clay         28             A
# 320   2015-2276            Zagreb    Hard         28             A
# 431    2015-533         Sao Paulo    Clay         28             A
# 435    2015-499      Delray Beach    Hard         32             A
# 463    2015-496         Marseille    Hard         28             A
# 761    2015-403     Miami Masters    Hard         96             M
# 803    2015-360        Casablanca    Clay         28             A
# ...

# %% [markdown]
# ##### add month columns in wording and in number

# %%
# Month name (e.g., "January")
df['tourney_month_name'] = df['tourney_date'].dt.month_name()

# Month number (e.g., 1 for January)
df['tourney_month_num'] = df['tourney_date'].dt.month

# %%
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0   2015-339     Brisbane    Hard         28             A   2015-01-04
# 1   2015-339     Brisbane    Hard         28             A   2015-01-04
# 2   2015-339     Brisbane    Hard         28             A   2015-01-04
# 3   2015-339     Brisbane    Hard         28             A   2015-01-04
# 4   2015-339     Brisbane    Hard         28             A   2015-01-04
#
#    match_num  winner_id  winner_seed winner_entry      winner_name  \
# 0          1     105357            0           WC     John Millman
# 1          2     103813            0            D  Jarkko Nieminen
# 2          3     105902            0           WC  James Duckworth
# 3          4     104871            0            D    Jeremy Chardy
# 4          5     105373            0            D    Martin Klizan
#
#   winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# 0           R        183        AUS        25.6          153
# ...

# %% [markdown]
# #### Working on outliers

# %% [markdown]
# ##### Summary of all Outliers

# %%
def outlier_summary(df):
    summary = []
    for col in df.select_dtypes(include=['int64', 'float64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        count_outliers = df[(df[col] < lower) | (df[col] > upper)][col].count()

        summary.append({
            'column': col,
            'outliers': count_outliers,
            'percent': round(100 * count_outliers / len(df), 3),
            'min': df[col].min(),
            'max': df[col].max(),
            'Q1': Q1,
            'Q3': Q3
        })

    return pd.DataFrame(summary).sort_values(by="percent", ascending=False)

outlier_df = outlier_summary(df)
outlier_df
# Out:
#                 column  outliers  percent       min       max         Q1  \
# 14             best_of       508   19.316       3.0       5.0       3.00
# 9           loser_seed       431   16.388       0.0      33.0       0.00
# 7   winner_rank_points       430   16.350       0.0   15785.0     738.50
# 1            match_num       248    9.430       1.0     127.0      10.00
# 3          winner_seed       238    9.049       0.0      32.0       0.00
# 13   loser_rank_points       227    8.631       0.0   15285.0     547.25
# 4            winner_ht       194    7.376     163.0     208.0     183.00
# 12          loser_rank       190    7.224       0.0    1410.0      31.00
# 10            loser_ht       137    5.209     163.0     208.0     183.00
# 6          winner_rank       130    4.943       0.0    1184.0      14.00
# 16               w_ace       130    4.943       0.0      53.0       3.00
# 15             minutes       118    4.487       8.0     252.0      80.00
# ...

# %%
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0   2015-339     Brisbane    Hard         28             A   2015-01-04
# 1   2015-339     Brisbane    Hard         28             A   2015-01-04
# 2   2015-339     Brisbane    Hard         28             A   2015-01-04
# 3   2015-339     Brisbane    Hard         28             A   2015-01-04
# 4   2015-339     Brisbane    Hard         28             A   2015-01-04
#
#    match_num  winner_id  winner_seed winner_entry      winner_name  \
# 0          1     105357            0           WC     John Millman
# 1          2     103813            0            D  Jarkko Nieminen
# 2          3     105902            0           WC  James Duckworth
# 3          4     104871            0            D    Jeremy Chardy
# 4          5     105373            0            D    Martin Klizan
#
#   winner_hand  winner_ht winner_ioc  winner_age  winner_rank  \
# 0           R        183        AUS        25.6          153
# ...

# %%
df.describe()
# Out:
#        draw_size                   tourney_date  match_num      winner_id  \
# count     2630.0                           2630     2630.0         2630.0
# mean   58.074525  2015-05-30 19:47:35.361216768  29.060076  105014.180228
# min          8.0            2015-01-04 00:00:00        1.0       100644.0
# 25%         28.0            2015-03-12 00:00:00       10.0       104527.0
# 50%         32.0            2015-05-24 00:00:00       20.5       104890.0
# 75%         96.0            2015-08-16 00:00:00       36.0       105379.0
# max        128.0            2015-11-15 00:00:00      127.0       144719.0
# std    38.739405                            NaN  27.762513    1719.325737
#
#        winner_seed   winner_ht   winner_age  winner_rank  winner_rank_points  \
# count       2630.0      2630.0  2630.000000       2630.0              2630.0
# mean      3.736122  187.443726    28.087110    52.263878         2228.407224
# ...

# %% [markdown]
# ##### Winner_rank/ Winner_rank_points/ Loser_rank/ Loser_rank_points/ Minutes
# ##### Will keep winner and loser rank_points as is

# %% [markdown]
# ##### Minutes Outliers (will keep upper side and replace lower side due to RET with median)

# %%
fig = px.box(df, y="minutes", points="all", color_discrete_sequence=["crimson"])
fig.update_layout(title="Match Duration Outliers")
fig.show()

# %%
Q1_m = df['minutes'].quantile(0.25)
Q3_m = df['minutes'].quantile(0.75)
IQR_m = Q3_m - Q1_m

lower_m = Q1_m - 1.5 * IQR_m
upper_m = Q3_m + 1.5 * IQR_m

median_minutes = df['minutes'].median()

# %%
df['minutes'] = np.where(
    df['minutes'] < lower_m,
    median_minutes,
    df['minutes']
)

# %% [markdown]
# ##### Winner_rank outliers

# %%
Q1 = df['winner_rank'].quantile(0.25)
Q3 = df['winner_rank'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

median_rank = df['winner_rank'].median()

# %%
df['winner_rank'] = np.where(
    (df['winner_rank'] < lower) | (df['winner_rank'] > upper),
    median_rank,
    df['winner_rank']
)

# %% [markdown]
# ##### Loser_rank outliers

# %%
Q1 = df['loser_rank'].quantile(0.25)
Q3 = df['loser_rank'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

median_rank = df['loser_rank'].median()

# %%
df['loser_rank'] = np.where(
    (df['loser_rank'] < lower) | (df['loser_rank'] > upper),
    median_rank,
    df['loser_rank']
)

# %%
df.describe()
# Out:
#        draw_size                   tourney_date  match_num      winner_id  \
# count     2630.0                           2630     2630.0         2630.0
# mean   58.074525  2015-05-30 19:47:35.361216768  29.060076  105014.180228
# min          8.0            2015-01-04 00:00:00        1.0       100644.0
# 25%         28.0            2015-03-12 00:00:00       10.0       104527.0
# 50%         32.0            2015-05-24 00:00:00       20.5       104890.0
# 75%         96.0            2015-08-16 00:00:00       36.0       105379.0
# max        128.0            2015-11-15 00:00:00      127.0       144719.0
# std    38.739405                            NaN  27.762513    1719.325737
#
#        winner_seed   winner_ht   winner_age  winner_rank  winner_rank_points  \
# count       2630.0      2630.0  2630.000000  2630.000000              2630.0
# mean      3.736122  187.443726    28.087110    40.528137         2228.407224
# ...

# %% [markdown]
# ### Saving df after cleaning

# %%
df.to_csv('/Users/klaymouna/Documents/CDSP/projects/final_project/atp_matches_2015_updated.csv', index=False)

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Univariate analysis

# %% [markdown]
# ##### Age

# %% [markdown]
# Insights:
#
# •  Winner and loser ages appear within the normal ATP range (generally 18–38).
#
# •   Distribution is slightly skewed toward the early–mid 20s, which aligns with typical peak tennis performance ages.
#
# •   Very young or very old players occur rarely but are valid tennis cases (rising talents, veterans).

# %%
# winner age

fig = px.histogram(
    df, 
    x="winner_age", 
    nbins=40, 
    marginal="box",
    color_discrete_sequence=["orange"]
)
fig.update_layout(title="Distribution of Winner Age")
fig.show()

# %%
# loser age

fig = px.histogram(
    df, 
    x="loser_age", 
    nbins=40, 
    marginal="box",
    color_discrete_sequence=["crimson"]
)
fig.update_layout(title="Distribution of Loser Age")
fig.show()

# %% [markdown]
# ##### Duration

# %% [markdown]
# Insights:
#
# • Match duration shows a right-skewed distribution, with most matches ending around a typical central value and a long tail of long, competitive matches.
#
# • Upper outliers (very long matches) are kept because they represent legitimate and important tennis realities (long battles, tiebreak-heavy matches, etc.).
#
# • Lower outliers (very short matches) were corrected, likely caused by retirements or incomplete matches.

# %%
# Duration (minutes cleaned from lower end)

fig = px.box(
    df, 
    y="minutes",
    color_discrete_sequence=["crimson"]
)
fig.update_layout(title="Match Duration (Minutes)")
fig.show()

# %% [markdown]
# ##### Hand

# %% [markdown]
# Insights: Right-handed players dominate, with very few left-handers and rare unknowns.

# %%
# Hands

df['winner_hand'].value_counts().to_frame()
# Out:
#              count
# winner_hand
# R             2231
# L              375
# U               24

# %%
df['loser_hand'].value_counts().to_frame()
# Out:
#             count
# loser_hand
# R            2164
# L             404
# U              62

# %% [markdown]
# ##### Surface

# %% [markdown]
# Insights: Hard courts dominate the dataset and Grass with much lower Clay courts tournaments in comparison (4 Grand Slams, 2 of them are Hard courts, Australian and US Open)

# %%
# Surface

df['surface'].value_counts().to_frame()
# Out:
#          count
# surface
# Hard      1503
# Clay       806
# Grass      321

# %%
fig = px.bar(
    df["surface"].value_counts().reset_index(),
    x="count", y="surface",
    color="count",
    color_discrete_sequence=["green", "royalblue", "orange", "crimson"]
)
fig.update_layout(
    title="Surface Distribution",
    xaxis_title="Surface",
    yaxis_title="Count"
)
fig.show()

# %% [markdown]
# ##### Tournaments

# %% [markdown]
# Insights: Grand Slams (Roland Garros, Australian Open, US Open, Wimbledon) have the highest match counts, each with 127 matches.

# %%
# Tournament matches

df['tourney_name'].value_counts().to_frame()
# Out:
#                       count
# tourney_name
# Roland Garros           127
# Australian Open         127
# US Open                 127
# Wimbledon               127
# Miami Masters            95
# Indian Wells Masters     95
# Cincinnati Masters       55
# Rome Masters             55
# Madrid Masters           55
# Canada Masters           55
# Shanghai Masters         55
# Monte Carlo Masters      55
# Paris Masters            47
# Winston-Salem            47
# Barcelona                47
# Washington               47
# Nottingham               47
# Halle                    31
# London                   31
# Beijing                  31
# Dubai                    31
# Acapulco                 31
# Rio de Janeiro           31
# Tokyo                    31
# Delray Beach             31
# Rotterdam                31
# Newport                  31
# Vienna                   31
# Basel                    31
# Hamburg                  31
# Doha                     31
# ...

# %% [markdown]
# ##### Level

# %% [markdown]
# Insights:
#
# • The dataset includes: G (Grand Slam), M (Masters 1000), A (ATP 500), F (Tour Finals).
# • A level tournaments are more common throughout the year
#
# • G are Grand Slams which are only 4 tournaments, however they have 128 draw size that cause higher number of matches
#
# • Tour Finals (F) has least stats throughout the analysis, which is normal for top-tier tournament that is played only once a year

# %%
# Level distribution

df['tourney_level'].value_counts().to_frame()
# Out:
#                count
# tourney_level
# A               1540
# M                567
# G                508
# F                 15

# %%
fig = px.bar(
    df['tourney_level'].value_counts().reset_index(),
    x='count', y='tourney_level',
    color="count",
    color_discrete_sequence=["orange", "royalblue", "crimson", "green"]
)
fig.update_layout(
    title="Tournament Level Distribution",
    xaxis_title="Level",
    yaxis_title="Count"
)
fig.show()

# %% [markdown]
# ##### Entry, Seed and Rank

# %% [markdown]
# Insights:
#
# •   Both winner_rank and loser_rank have undergone identical outlier treatment mentioned before
#
# •   Most players are Direct entrants which is the normal case
#
# •   Players if not direct entrants, most probably they are Qualifirers or Wild Card because this happens almost in all tournaments
#
# •    Lucky Losers and Protected Ranking are also low in count less that 100 times for all players
#
# •   S for Spesial Entry is Extremely Rare that happened only once in the year
#
# •   Extreme, unrealistic ranking spikes have been smoothed by replacing outliers with the median. Winner and Loser Rank will be used in next analysis not their points to neglect the extreme values in the Ranking Points of Top elite ATP players

# %%
# Entry, Seed and Rank

df['winner_entry'].value_counts().to_frame()
# Out:
#               count
# winner_entry
# D              2304
# Q               181
# WC              120
# LL               15
# PR               10

# %%
fig = px.histogram(
    df, 
    x="winner_rank", 
    nbins=40,
    color_discrete_sequence=["orange"]
)
fig.update_layout(title="Winner Rank Distribution")
fig.show()

# %%
print(df['winner_rank'].mean())
print(df['winner_rank'].median())
# Out:
# 40.528136882129274
# 36.0

# %%
df['winner_seed'].value_counts().to_frame()
# Out:
#              count
# winner_seed
# 0             1281
# 1              193
# 2              147
# 3              129
# 4              116
# 5              115
# 6              111
# 8              102
# 7               98
# 12              37
# 9               31
# 14              29
# 13              27
# 16              26
# 15              23
# 10              20
# 18              13
# 11              12
# 22              11
# 17              10
# 23              10
# 32              10
# 20              10
# 27               9
# 21               8
# 24               8
# 26               8
# 29               7
# 19               7
# 28               6
# 31               6
# 25               5
# 30               5

# %%
df['loser_entry'].value_counts().to_frame()
# Out:
#              count
# loser_entry
# D             2020
# Q              345
# WC             216
# LL              33
# PR              15
# S                1

# %%
fig = px.histogram(
    df, 
    x="loser_rank", 
    nbins=40,
    color_discrete_sequence=["crimson"]
)
fig.update_layout(title="Loser Rank Distribution")
fig.show()

# %%
print(df['loser_rank'].mean())
print(df['loser_rank'].median())
# Out:
# 62.07490494296578
# 60.0

# %%
df['loser_seed'].value_counts().to_frame()
# Out:
#             count
# loser_seed
# 0            1928
# 7              67
# 6              67
# 8              64
# 3              62
# 5              61
# 4              61
# 2              55
# 1              32
# 9              19
# 16             17
# 13             17
# 15             17
# 14             17
# 12             17
# 10             17
# 11             16
# 20              6
# 18              6
# 19              6
# 31              6
# 29              6
# 23              6
# 17              6
# 32              6
# 28              6
# 22              6
# 26              6
# 30              6
# 21              6
# 27              6
# 25              6
# 24              5
# 33              1

# %% [markdown]
# ##### Time

# %% [markdown]
# Insights: August has the highest number of matches, followed by February and May. (Each tournament has only one date for all its matches)

# %%
df['tourney_month_name'].value_counts().to_frame()
# Out:
#                     count
# tourney_month_name
# August                358
# February              344
# May                   291
# June                  290
# January               266
# April                 264
# October               260
# July                  197
# March                 190
# September             108
# November               62

# %%
monthly = df.groupby(["tourney_month_num", "tourney_month_name"]).size().reset_index(name="count")
monthly = monthly.sort_values("tourney_month_num")

fig = px.bar(
    monthly,
    x="tourney_month_name",
    y="count",
    title="Matches Per Month",
    color="tourney_month_name",
    color_discrete_sequence=px.colors.qualitative.Set3
)

fig.update_layout(
    xaxis_title="Month",
    yaxis_title="Match Count"
)

fig.show()

# %%
fig = px.histogram(
    df, 
    x="tourney_date",
    color_discrete_sequence=["royalblue"]
)
fig.update_layout(title="Matches Per Date")
fig.show()

# %% [markdown]
# ##### Aces

# %% [markdown]
# Insights: Aces are heavily right-skewed, with a few power servers creating large values. This is expected in ATP matches, especially on hard courts and in ATP Finals

# %%
# Winner aces

fig = px.histogram(
    df, 
    x="w_ace",
    nbins=40,
    color_discrete_sequence=["orange"]
)
fig.update_layout(title="Winner Aces Distribution")
fig.show()

# %%
# loser aces

fig = px.histogram(
    df, 
    x="l_ace",
    nbins=40,
    color_discrete_sequence=["crimson"]
)
fig.update_layout(title="Loser Aces Distribution")
fig.show()

# %% [markdown]
# ##### Double Faults

# %% [markdown]
# Insights: Double Faults are right-skewed but not extreme. Indicates that most players double fault a few times per match, with occasional high-risk players producing spikes

# %%
# Double Faults

fig = px.histogram(df, x="w_df", nbins=40, title="Winner Double Faults",
                   color_discrete_sequence=["orange"], marginal="box")
fig.show()

fig = px.histogram(df, x="l_df", nbins=40, title="Loser Double Faults",
                   color_discrete_sequence=["crimson"], marginal="box")
fig.show()

# %% [markdown]
# ##### First serve

# %% [markdown]
# Insights:
#
# • 1st serve won: slightly right-skewed for winners. All serve-related metrics show expected positive skew, where a few players produce extremely high counts
#
# • Also, these extreme values becomes more rare among losers. - 1st serve in: centered around typical ATP values

# %%
# First serve won

fig = px.histogram(
    df, 
    x="w_1stWon",
    nbins=40,
    color_discrete_sequence=["orange"]
)
fig.update_layout(title="Winner 1st Serve Points Won")
fig.show()

# %%
fig = px.histogram(
    df, 
    x="l_1stWon",
    nbins=40,
    color_discrete_sequence=["crimson"]
)
fig.update_layout(title="Loser 1st Serve Points Won")
fig.show()

# %%
fig = px.histogram(
    df, 
    x="w_1stIn",
    nbins=40,
    color_discrete_sequence=["orange"]
)
fig.update_layout(title="Winner 1st Serve Points In")
fig.show()

# %%
fig = px.histogram(
    df, 
    x="l_1stIn",
    nbins=40,
    color_discrete_sequence=["crimson"]
)
fig.update_layout(title="Loser 1st Serve Points In")
fig.show()

# %% [markdown]
# ##### Break Points

# %% [markdown]
# Insights:
#
# • Break Points are highly dependent on match duration and pressure
#
# • Most of break points faced or saved are less than 5 closer to 0 and both distributions are very similar which means both variables are highly correlated
#
# • Outliers correspond to long or very tight matches and they are rare
#
# • Losers Face more break points than Winners who have more count close to 0
#
# • Losers saved less of the break points they faced when count goes over 10

# %%
# break points saved

for col in ["w_bpSaved", "w_bpFaced"]:
    fig = px.histogram(df, x=col, nbins=40,
                       title=f"Distribution of {col}",
                       color_discrete_sequence=["orange"], marginal="box")
    fig.show()

# %%
# break points saved (loser)

for col in ["l_bpSaved", "l_bpFaced"]:
    fig = px.histogram(df, x=col, nbins=40,
                       title=f"Distribution of {col}",
                       color_discrete_sequence=["crimson"], marginal="box")
    fig.show()

# %% [markdown]
# ##### Serve points

# %% [markdown]
# Insights: Serve Points are Right-skewed due to match length and number of service games. Grand Slams can produce very long matches. While other tournaments tend to be shorter on average

# %%
# Serve points: 
fig = px.histogram(df, x="w_svpt", nbins=40, 
title="Winner Serve Points (w_svpt)",
color_discrete_sequence=["orange"],
marginal="box")
fig.show()

fig = px.histogram(df, x="l_svpt", nbins=40, 
title="Loser Serve Points (l_svpt)",
color_discrete_sequence=["crimson"],
marginal="box")
fig.show()

# %% [markdown]
# ##### Player Height

# %% [markdown]
# Insights:
#
# • Heights show a clean normal-like distribution
#
# • Range from 185-190 dominates the height distribution

# %%
# Player Height

fig = px.histogram(df, x="winner_ht", nbins=40,
                   title="Winner Height Distribution",
                   color_discrete_sequence=["orange"], marginal="box")
fig.show()

# %%
fig = px.histogram(df, x="loser_ht", nbins=40,
                   title="Loser Height Distribution",
                   color_discrete_sequence=["crimson"], marginal="box")
fig.show()

# %% [markdown]
# ##### Round

# %% [markdown]
# Insights: Round 128 matches is lower than R32 because only 4 Grand Slam tournaments that include R128 and only 2 Masters, also R64 is included in Grand Slams and 1000 Masters tournaments (total 16 Tournaments out of 66 annual tournaments)

# %%
import pandas as pd

df = pd.read_csv("atp_matches_2015_updated.csv")

# List tournaments with R128
r128_tourneys = (
    df[df["round"] == "R128"]
    .groupby([ "tourney_name", "tourney_level"])
    .size()
    .reset_index(name="matches_with_R128")
)

# List tournaments with R64
r64_tourneys = (
    df[df["round"] == "R64"]
    .groupby(["tourney_name", "tourney_level"])
    .size()
    .reset_index(name="matches_with_R64")
)

print("Tournaments containing Round of 128:")
print(r128_tourneys)

print("\nTournaments containing Round of 64:")
print(r64_tourneys)
# Out:
# Tournaments containing Round of 128:
#            tourney_name tourney_level  matches_with_R128
# 0       Australian Open             G                 64
# 1  Indian Wells Masters             M                 32
# 2         Miami Masters             M                 32
# 3         Roland Garros             G                 64
# 4               US Open             G                 64
# 5             Wimbledon             G                 64
#
# Tournaments containing Round of 64:
#             tourney_name tourney_level  matches_with_R64
# 0        Australian Open             G                32
# 1              Barcelona             A                16
# 2         Canada Masters             M                24
# 3     Cincinnati Masters             M                24
# 4   Indian Wells Masters             M                32
# 5         Madrid Masters             M                24
# 6          Miami Masters             M                32
# ...

# %%
# Double Faults

fig = px.histogram(df, x="round", title="Tournament Round",
                   color_discrete_sequence=["Blue"], marginal="box")
fig.show()

# %% [markdown]
# #### Bivariate Analysis and Insights

# %% [markdown]
# ##### Q1: How do winner aces (w_ace) vary by surface?

# %% [markdown]
# Insight: Aces have higher median Grass then on Hard and lowest on Clay surface. Larger IQRs and upper outliers on fast surfaces. This means that Grass is the fastest court surface among all

# %%
fig = px.box(df, x="surface", y="w_ace",
             title="Winner Aces by Surface",
             color="surface",
             color_discrete_sequence=["#636EFA","#EF553B","#00CC96"])
fig.update_layout(xaxis_title="Surface", yaxis_title="Winner Aces")
fig.show()

# %% [markdown]
# ##### Q2: Relationship between winner aces (w_ace) and winner height (winner_ht).

# %% [markdown]
# Insight: Taller players tend to serve stronger, positive correlation; outliers reveal elite tallest-servers

# %%
fig = px.scatter(df, x="winner_ht", y="w_ace",
                 trendline="ols",
                 title="Winner Aces vs Winner Height",
                 color_discrete_sequence=["#AB63FA"])
fig.update_layout(xaxis_title="Winner Height (cm)", yaxis_title="Winner Aces")
fig.show()

# %% [markdown]
# ##### Q3: How does match length (minutes) differ across tourney_level?

# %% [markdown]
# Insight: It's clear that 3-set based tournaments (M & A & F) tend to be on the same level of duration, while G (Grand Slam) is a 5-set based tournaments

# %%
fig = px.box(df, x="tourney_level", y="minutes",
             title="Match Duration (minutes) by Tournament Level",
             color="tourney_level",
             color_discrete_sequence=["#FFA15A","#19D3F3","#FF6692","#B6E880"])
fig.update_layout(xaxis_title="Tournament Level", yaxis_title="Minutes")
fig.show()

# %% [markdown]
# ##### Q4: Relationship between minutes and number of sets (sets_num).

# %% [markdown]
# Insight: More sets → longer minutes.

# %%
fig = px.scatter(df, x="sets_num", y="minutes",
                 title="Match Duration vs Number of Sets",
                 color_discrete_sequence=["#FF97FF"],
                 marginal_y="box")
fig.update_layout(xaxis_title="Sets Number", yaxis_title="Minutes")
fig.show()

# %% [markdown]
# ##### Q5:  Correlation between winner_rank and loser_rank (how often tightly-ranked players meet).

# %% [markdown]
# Insight: Points near diagonal: tight matches. Many points (matches) with large rank gaps indicate early rounds / mismatches

# %%
fig = px.scatter(df, x="winner_rank", y="loser_rank",
                 title="Winner Rank vs Loser Rank",
                 color_discrete_sequence=["#00CC96"], opacity=0.6)
fig.update_layout(xaxis_title="Winner Rank", yaxis_title="Loser Rank")
fig.show()

# %% [markdown]
# ##### Q6: How do winner_rank and winner_age relate?

# %% [markdown]
# Insight: It seems that peak performance ages usually mid–late 20s

# %%
fig = px.scatter(df, x="winner_age", y="winner_rank",
                 title="Winner Rank vs Winner Age",
                 color_discrete_sequence=["#FFA15A"], trendline="lowess")
fig.update_layout(xaxis_title="Winner Age", yaxis_title="Winner Rank (lower=better)")
fig.show()

# %% [markdown]
# ##### Q7: Winner first-serve points won (w_1stWon) vs winner first-serve in (w_1stIn) (efficiency).

# %% [markdown]
# Insight: High w_1stIn + high w_1stWon = dominant serving. Points off the diagonal show inefficiency or contextual match differences

# %%
fig = px.scatter(df, x="w_1stIn", y="w_1stWon",
                 title="Winner 1stServe Won vs 1stServe In",
                 color_discrete_sequence=["#636EFA"])
fig.update_layout(xaxis_title="Winner 1st Serve In", yaxis_title="Winner 1st Serve Points Won")
fig.show()

# %% [markdown]
# ##### Q8: Winner double faults (w_df) vs winner rank (winner_rank) — does rank predict DF?

# %% [markdown]
# Insight: Lower-ranked players may double-fault more. Top 10 players DF least

# %%
fig = px.box(df, x=pd.cut(df["winner_rank"], bins=[1,10,50,150,1000], labels=["Top10","11-50","51-150","150+"]),
             y="w_df",
             title="Winner Double Faults by Rank Group",
             color_discrete_sequence=["#EF553B"])
fig.update_layout(xaxis_title="Winner Rank Group", yaxis_title="Winner Double Faults")
fig.show()

# %% [markdown]
# ##### Q9:  Winner aces (w_ace) vs minutes — do longer matches mean more aces?

# %% [markdown]
# Insight: Positive trend possible (longer matches → more service games → more aces)

# %%
fig = px.scatter(df, x="minutes", y="w_ace",
                 title="Winner Aces vs Match Minutes",
                 color_discrete_sequence=["#00CC96"], opacity=0.6)
fig.update_layout(xaxis_title="Minutes", yaxis_title="Winner Aces")
fig.show()

# %% [markdown]
# ##### Q10: How does Winner Break Points Saved (w_bpSaved) vary across Tournament Level (tourney_level)?

# %% [markdown]
# Insight:
#
# • G level tournaments are 5-set based → so more BP chances for more games played
#
# • Lower-level rounds (M & A) have lower break opportunities → less break points saved
#
# • ATP Finals (F) show tight serve performance → low BP counts

# %%
fig = px.box(df, x="tourney_level", y="w_bpSaved",
             title="Winner Break Points Saved by Tournament Level",
             color="tourney_level",
             color_discrete_sequence=["#636EFA","#EF553B","#00CC96","#FFA15A"])
fig.update_layout(xaxis_title="Tournament Level", yaxis_title="Winner Break Points Saved")
fig.show()

# %% [markdown]
# ##### Q11:  Winner serve points (w_svpt) vs minutes — serve points scale with match length.

# %% [markdown]
# Insight:  Strong linear relationship expected; outliers identify long marathons

# %%
fig = px.scatter(df, x="minutes", y="w_svpt",
                 title="Winner Serve Points vs Minutes",
                 color_discrete_sequence=["#FF6692"], opacity=0.6)
fig.update_layout(xaxis_title="Minutes", yaxis_title="Winner Serve Points")
fig.show()

# %% [markdown]
# ##### Q12: Winner entry (winner_entry) (e.g., Q, WC, SE, etc.) vs winner_rank — do wildcards/qualifiers differ in rank?

# %% [markdown]
# Insight: Highest ranks for the Direct entrants, which is expected vs. Wild card, Qualifiers and Protected Ranks entrants who typically have worse ranks

# %%
fig = px.box(df, x="winner_entry", y="winner_rank",
             title="Winner Rank by Entry Type",
             color="winner_entry",
             color_discrete_sequence=px.colors.qualitative.Set2)
fig.update_layout(xaxis_title="Winner Entry Type", yaxis_title="Winner Rank")
fig.show()

# %% [markdown]
# ##### Q13: Winner hand (winner_hand) vs w_ace — does handedness affect aces?

# %% [markdown]
# Insight: Left and right handers are close in the Ace profile, while extreme values are more in the right handers

# %%
fig = px.box(df, x="winner_hand", y="w_ace",
             title="Winner Aces by Hand",
             color="winner_hand",
             color_discrete_sequence=["#636EFA","#EF553B","#00CC96","#FFA15A"])
fig.update_layout(xaxis_title="Winner Hand", yaxis_title="Winner Aces")
fig.show()

# %% [markdown]
# ##### Q14: Loser double faults (l_df) vs surface — are DF more common on certain surfaces?

# %% [markdown]
# Insight: Grass and Hard courts got the higher Aces and now also slightly higher in Double Faults than Clay courts, it seems that the faster the ball in a specific court cause higher probability of either Aces or Double Faults

# %%
fig = px.box(df, x="surface", y="l_df",
             title="Loser Double Faults by Surface",
             color="surface",
             color_discrete_sequence=["#EF553B","#00CC96","#636EFA"])
fig.update_layout(xaxis_title="Surface", yaxis_title="Loser Double Faults")
fig.show()

# %% [markdown]
# ##### Q15: Winner_bpSaved (w_bpSaved) vs winner_rank — do top players save more break points?

# %% [markdown]
# Insight: The lower the winner rank (70+ rank) the less ability to save break points, and the higher ranked players save more break points

# %%
fig = px.scatter(df, x="winner_rank", y="w_bpSaved",
                 title="Winner Break Points Saved vs Winner Rank",
                 color_discrete_sequence=["#00CC96"], opacity=0.6)
fig.update_layout(xaxis_title="Winner Rank", yaxis_title="Winner Break Points Saved")
fig.show()

# %% [markdown]
# ##### Q16: Winner 2ndServe Won (w_2ndWon) vs loser 1stServe Won (l_1stWon) — interplay of second-serve solidity vs opponent’s first-serve effectiveness.

# %% [markdown]
# Insight: It proves that in case loser is getting first serve, the winner gets high second serve as a kind of come back or resilience, and the more right upper points are a very competitive matches

# %%
fig = px.scatter(df, x="w_2ndWon", y="l_1stWon",
                 title="Winner 2nd Serve Won vs Loser 1st Serve Won",
                 color_discrete_sequence=["#FFA15A"], opacity=0.6)
fig.update_layout(xaxis_title="Winner 2nd Serve Points Won", yaxis_title="Loser 1st Serve Points Won")
fig.show()

# %% [markdown]
# ##### Q17: Question: Draw size (draw_size) vs winner_rank — do small draws (Finals) concentrate top-ranked winners?

# %% [markdown]
# Insight:
#
# • Winners always have tendency to lower tail which means that they are the higher ranked players who are most probably win
#
# • Tour finals that has only 8 draw size is exclusive on elite top-ranked players

# %%
df["draw_size"] = df["draw_size"].astype(str)

fig = px.box(df, x="draw_size", y="winner_rank",
             title="Winner Rank by Draw Size",
             color="draw_size",
             color_discrete_sequence=px.colors.qualitative.Set2)

fig.update_layout(
    xaxis_title="Draw Size (Actual Tournament Sizes)",
    yaxis_title="Winner Rank"
)

fig.show()

# %% [markdown]
# ##### Q18: Winner_seed vs winner_rank — does seed reflect actual ranking?

# %% [markdown]
# Insight:
#
# • Seed 1 should correlate with low rank numbers (high ranked players) and they are correlated from 1 to 32 because the seeds in the tournament are reflection to the players ATP rank
#
# • High rank numbers from 1 to 8 seed shows low level tournaments that include low ranked players as high seeders
#
# • Noisy 0 seeds/NaNs indicate unseeded winners who are very high in rank number (low ranked players)

# %%
fig = px.scatter(df.dropna(subset=["winner_seed"]), x="winner_seed", y="winner_rank",
                 title="Winner Seed vs Winner Rank",
                 color_discrete_sequence=["#EF553B"], opacity=0.7)
fig.update_layout(xaxis_title="Winner Seed", yaxis_title="Winner Rank")
fig.show()

# %% [markdown]
# ##### Q19: Sets number (sets_num) vs w_ace — do long (many-set) matches produce more aces for winners?

# %% [markdown]
# Insight: Higher aces in matches with more sets are expected because of more service games

# %%
fig = px.box(df, x="sets_num", y="w_ace",
             title="Winner Aces by Number of Sets",
             color_discrete_sequence=["#00CC96"])
fig.update_layout(xaxis_title="Number of Sets", yaxis_title="Winner Aces")
fig.show()

# %% [markdown]
# ##### Q20: Winner age (winner_age) vs w_ace — do older (experienced) players serve more/less aces?

# %% [markdown]
# Insight: The trend is slightly upward, with higher ages can get more aces, and we can see that extreme values increase when age increases

# %%
fig = px.scatter(df, x="winner_age", y="w_ace",
                 trendline="lowess",
                 title="Winner Age vs Winner Aces",
                 color_discrete_sequence=["#636EFA"])
fig.update_layout(xaxis_title="Winner Age", yaxis_title="Winner Aces")
fig.show()

# %% [markdown]
# ##### Q21: Round vs. W_Rank and W_Aces

# %% [markdown]
# Insight: Round does not relate so high in aces of winner, however it's clear that rank goes higher (low in number) when go further in the tournament, RR goes for the Tour Finals that include top ATP ranked players of the year

# %%
fig = px.box(
    df, x="round", y="w_ace",
    title="Winner Aces by Tournament Round"
)
fig.show()

# %%
fig = px.box(
    df, x="round", y="winner_rank",
    title="Winner Ranking Distribution by Round"
)
fig.show()

# %% [markdown]
# #### Multivariate Analysis and Insights

# %% [markdown]
# ##### Q21: How do match minutes change across both surface and tournament level?

# %% [markdown]
# Insight:
#
# • Clay is longest in Grand slams, due to slower surface causes easier ball return
#
# • Grand slams are the longest regardless of the surface
#
# • Finals are always the shortest
#
# • No Masters 1000 level tournaments are played on Grass court
#
# • Tour finals are played on a Hard Surface

# %%
fig = px.box(df, x="surface", y="minutes",
             color="tourney_level",
             title="Minutes by Surface and Tournament Level",
             color_discrete_sequence=px.colors.qualitative.Set1)
fig.update_layout(yaxis_title="Minutes")
fig.show()

# %% [markdown]
# ##### Q22: Do winner aces behave differently across ranks and surfaces?

# %% [markdown]
# Insight:
#
# • Aces are hugely concentrated in the lower left, start to be less going to the right and least starting rank (70+)
#
# • Extreme Aces are more in Hard and Grass regardless of the rank
#
# • Extreme Aces also concentrated more in the top 30 ranked players area
#
# • Same reason of duration in Clay courts applies here, that slower ball makes Aces less

# %%
fig = px.scatter(df, x="winner_rank", y="w_ace",
                 color="surface",
                 title="Winner Aces vs Winner Rank by Surface",
                 opacity=0.6)
fig.update_layout(xaxis_title="Winner Rank", yaxis_title="Winner Aces")
fig.show()

# %% [markdown]
# ##### Q23: How do winner_age and winner_rank together relate to match length?

# %% [markdown]
# Insight:
#
# • Most matches are in the mid-age area from 22-35 and less than 150 minutes
#
# • Most long matches come from mid-aged, high-rank players

# %%
fig = px.scatter(df, x="winner_age", y="minutes",
                 color="winner_rank",
                 title="Minutes vs Winner Age Colored by Winner Rank",
                 color_continuous_scale="Viridis", opacity=0.7)
fig.update_layout(xaxis_title="Winner Age", yaxis_title="Minutes")
fig.show()

# %% [markdown]
# ##### Q24: How does first serve performance change across surfaces?

# %% [markdown]
# Insight: Hard and Grass courts give better serve results than Clay

# %%
fig = px.scatter(df, x="w_1stIn", y="w_1stWon",
                 color="surface",
                 title="1st Serve Won vs 1st Serve In by Surface",
                 opacity=0.6)
fig.update_layout(xaxis_title="Winner 1st In", yaxis_title="Winner 1st Won")
fig.show()

# %% [markdown]
# ##### Q25: Do taller players hit more aces in different tournament levels?

# %% [markdown]
# Insight: Tall players hit more aces in all levels, especially high level tournaments.

# %%
fig = px.scatter(df, x="winner_ht", y="w_ace",
                 color="tourney_level",
                 title="Winner Aces vs Winner Height by Tournament Level",
                 opacity=0.6)
fig.update_layout(xaxis_title="Winner Height", yaxis_title="Winner Aces")
fig.show()

# %% [markdown]
# ##### Q26: How does sets_num connect with minutes across surface?

# %% [markdown]
# Insight: More sets = more minutes, Clay grows the most (slowest matches)

# %%
fig = px.scatter(df, x="sets_num", y="minutes",
                 color="surface",
                 title="Minutes vs Sets Number by Surface",
                 opacity=0.6)
fig.update_layout(xaxis_title="Number of Sets", yaxis_title="Minutes")
fig.show()

# %% [markdown]
# ##### Q27: How do serve points and aces relate across rank levels?

# %% [markdown]
# Insight: Top players produce aces with higher serve points

# %%
fig = px.scatter(df, x="w_svpt", y="w_ace",
                 color="winner_rank",
                 title="Aces vs Serve Points Colored by Winner Rank",
                 color_continuous_scale="Plasma", opacity=0.7)
fig.update_layout(xaxis_title="Winner Serve Points", yaxis_title="Winner Aces")
fig.show()

# %% [markdown]
# ##### Q28: Do aces and double faults move differently by surface?

# %% [markdown]
# Insight: Grass then Hard courts → more aces no matter the DF; Clay → lower ceiling

# %%
fig = px.scatter(df, x="w_df", y="w_ace",
                 color="surface",
                 title="Winner Aces vs Double Faults by Surface",
                 opacity=0.6)
fig.update_layout(xaxis_title="Winner Double Faults", yaxis_title="Winner Aces")
fig.show()

# %% [markdown]
# ##### Q29: Does first serve winning change by rank in different tournament levels?

# %% [markdown]
# Insight:
#
# • Higher-ranked players win more 1st-serve points in all levels
#
# • Extreme number of points won in 1st serve are always in Grand Slams regardless of the Winner Rank
#
# • High ranked players participate mostly in Gran Slams and Masters 1000

# %%
fig = px.scatter(df, x="winner_rank", y="w_1stWon",
                 color="tourney_level",
                 title="Winner 1st Serve Points Won vs Rank by Tournament Level",
                 opacity=0.7)
fig.update_layout(xaxis_title="Winner Rank", yaxis_title="Winner 1st Serve Points Won")
fig.show()

# %% [markdown]
# ##### Q30: How do age, rank, and serve consistency relate?

# %% [markdown]
# Insight: Prime-age (22-32) players with good ranks keep high 1st-serve consistency

# %%
fig = px.scatter(df, x="winner_age", y="w_1stIn",
                 color="winner_rank",
                 title="1st Serve In vs Winner Age Colored by Rank",
                 color_continuous_scale="Turbo", opacity=0.7)
fig.update_layout(xaxis_title="Winner Age", yaxis_title="Winner 1st Serve In")
fig.show()

# %% [markdown]
# ### General Insights

# %% [markdown]
# #### 1. ATP tennis follows a very consistent pattern in age, performance, and match behavior

# %% [markdown]
# •	Most active ATP players fall in the mid 20s to early 30s where performance peaks
#
# •	Veterans abovr mid 30s still exist but are rare, and extremely young players rarely show up
#
# •	Most long matches and high-intensity battles come from players in the prime range

# %% [markdown]
# #### 2. Tournament structure is the main driver of match dynamics, especially Grand Slams

# %% [markdown]
# •	Grand Slams dominate total match volume because of the 128-draw format
#
# •	They naturally produce longer matches, more break points, more serve points, more aces, and overall richer statistics
#
# •	Masters and ATP 500s show a completely different statistical shape because of smaller draws and 3-set formats

# %% [markdown]
# #### 3. Surface type strongly defines playing style and match outcomes

# %% [markdown]
# •	Grass and Hard encourage aggressive serving → more aces and double faults
#
# •	Clay slows the ball → reduces aces and increases match length

# %% [markdown]
# #### 4. Serving strength is the clearest indicator of match control

# %% [markdown]
# •	High 1st-serve-in combined with high 1st-serve-won indicates dominance
#
# •	Winners consistently show stronger serve profiles than losers
#
# •	Tall players naturally generate stronger serves across all levels and surfaces
#
# •	Top 10 players almost never produce extreme double fault counts due to control and consistency

# %% [markdown]
# #### 5. Ranking explains tournament progression very clearly

# %% [markdown]
# •	Better-ranked players (lower rank numbers) move deeper into tournaments
#
# •	Later rounds concentrate top-ranked players more tightly
#
# •	Round Robin (RR) belongs exclusively to Tour Finals, which include only elite players
#
# •	Unseeded players and Special/Protected entries show noticeably weaker rank profiles

# %% [markdown]
# #### 6. Many performance indicators are driven by match length, not skill

# %% [markdown]
# •	More sets → more minutes → more aces → more break points → more serve points
#
# •	Long matches create statistical outliers naturally, and these outliers are meaningful (not noise)
#
# •	Grand Slams show all of these effects because of 5-set format

# %% [markdown]
# #### 7. Winner–Loser patterns are structurally similar but shifted

# %% [markdown]
# •	Both follow similar distributions in serve stats, break points, and ranks
#
# •	Losers face more break points, save fewer, and generate fewer extreme values
#
# •	Serve stats for losers rarely reach extreme high values compared to winners

# %% [markdown]
# #### 8. Entry types reveal expected player quality differences

# %% [markdown]
# •	Direct entrants are by far the majority and represent high-level ranked players
#
# •	Qualifiers, Wild Cards, and Lucky Losers generally show worse ranks
#
# •	Protected Ranking appears rarely, and Special Entry almost never

# %% [markdown]
# #### 9. The tour calendar shapes match volume peaks

# %% [markdown]
# •	August is the highest match month, aligning with major tournaments
#
# •	February and May also stand out due to busy ATP schedules in those periods
#
# •	Each tournament places all matches within a single date range, explaining the monthly clustering

# %% [markdown]
# #### 10. Everything in the dataset behaves like real ATP tennis

# %% [markdown]
# •	Surfaces behave exactly as expected
#
# •	Player ages and heights follow realistic ATP distributions
#
# •	Rounds correspond logically to tournament progression
#
# •	Serve performance rises with height, ranking and surface
#
# •	Grand Slams show the highest statistical density
#
# •	Tournament levels follow the known ATP structure

# %% [markdown]
# ### Final Deduction

# %% [markdown]
# •	Top players dominate late rounds
#
# •	Surfaces dictate play style
#
# •	Grand Slams generate the deepest and richest matches
#
# •	Serve performance predicts success
#
# •	Ranking and seeding align logically
#
# •	Most match outliers are explainable, not data errors

# %% [markdown]
# ### Dashboards

# %%
# %%writefile /Users/klaymouna/Documents/CDSP/projects/final_project/app.py

import streamlit as st
import pandas as pd
import plotly.express as px
import numpy as np

# -------------------------------------------
# CONFIG
# -------------------------------------------
st.set_page_config(page_title="Tennis Dashboard", layout="wide")

DATA_PATH = "atp_matches_2015_updated.csv"  

@st.cache_data
def load_data(path):
    df = pd.read_csv(path)
    return df

try:
    df = load_data(DATA_PATH)
except:
    st.error("❌ Cannot load the CSV file. Make sure it is in the same folder as app.py.")
    st.stop()

# -------------------------------------------
# COLOR THEME
# -------------------------------------------
WIN_COLOR = "Orange"
LOS_COLOR = "Crimson"
NEUTRAL = "Blue"
# -------------------------------------------
# HELPER FUNCTIONS
# -------------------------------------------
def tidy_vc(df, col, top=None):
    """Return tidy value_counts: col, count"""
    if col not in df.columns:
        return None
    vc = df[col].value_counts().reset_index()
    vc.columns = [col, "count"]
    if top:
        vc = vc.head(top)
    return vc

def numeric_summary(df, cols):
    """Return numeric summary table for given columns."""
    rows = []
    for c in cols:
        if c in df.columns and pd.api.types.is_numeric_dtype(df[c]):
            s = df[c].dropna()
            rows.append({
                "metric": c,
                "count": int(s.count()),
                "mean": round(float(s.mean()), 0),
                "median": round(float(s.median()), 1),
                "min": round(float(s.min()), 1),
                "max": round(float(s.max()), 1),
                "std": round(float(s.std()), 1)
            })
    return pd.DataFrame(rows).set_index("metric")

def metric_row(kpis, cols=4):
    c = st.columns(cols)
    for (label, value), col in zip(kpis.items(), c):
        col.metric(label, value)

# -------------------------------------------
# SIDEBAR
# -------------------------------------------
st.sidebar.title("Navigation")
section = st.sidebar.radio("Go to:", [
    "Overview",
    "Tournament Details",
    "Winner Details",
    "Loser Details",
    "Match Details",
    "Winner Match Statistics",
    "Loser Match Statistics"
])

# -------------------------------------------
# KPIs
# -------------------------------------------
total_matches = len(df)
unique_tourneys = df["tourney_name"].nunique() if "tourney_name" in df else "-"
unique_winners = df["winner_name"].nunique() if "winner_name" in df else "-"
unique_losers = df["loser_name"].nunique() if "loser_name" in df else "-"
unique_players = len(pd.unique(df[["winner_name", "loser_name"]].values.ravel()))


# ======================================================================
# OVERVIEW
# ======================================================================
if section == "Overview":
    st.title("🎾 Tennis Data Overview (Totals)")

    metric_row({
        "Total Matches": f"{total_matches:,}",
        "Tournaments": f"{unique_tourneys:,}",
        "Winners": f"{unique_winners:,}",
        "Losers": f"{unique_losers:,}"
    })

    st.subheader("Dataset Sample")
    st.dataframe(df.head(10), use_container_width=True)

    st.subheader("Overall Numeric Summary")
    numeric_fields = [
        "minutes", "sets_num",
        "winner_age", "loser_age",
        "winner_ht", "loser_ht",
        "w_ace", "l_ace", "w_df", "l_df",
        "w_svpt", "l_svpt",
        "w_1stIn", "w_1stWon", "l_1stIn", "l_1stWon"
    ]
    numeric_cols = [c for c in numeric_fields if c in df.columns]

    if numeric_cols:
        st.dataframe(numeric_summary(df, numeric_cols))


# ======================================================================
# TOURNAMENT DETAILS
# ======================================================================
elif section == "Tournament Details":
    st.title("🏟 Tournament Details")

    # ------------------------------------------------------------
    # Matches per tournament (Top 30)
    # ------------------------------------------------------------
    vc_t = tidy_vc(df, "tourney_name", top=30)
    if vc_t is not None:
        st.subheader("Matches per Tournament (Top 30)")
        fig = px.bar(
            vc_t,
            x="tourney_name",
            y="count",
            title="Matches per Tournament",
            color_discrete_sequence=[NEUTRAL]
        )
        st.plotly_chart(fig, use_container_width=True)

    # ------------------------------------------------------------
    # Surface distribution
    # ------------------------------------------------------------
    vc_surf = tidy_vc(df, "surface")
    if vc_surf is not None:
        st.subheader("Matches per Surface")
        fig = px.pie(
            vc_surf,
            names="surface",
            values="count",
            title="Matches by Surface",
            color_discrete_sequence=[NEUTRAL, WIN_COLOR, LOS_COLOR]
        )
        st.plotly_chart(fig, use_container_width=True)

    # ------------------------------------------------------------
    # Monthly matches (CALENDAR ORDER — Using your structure)
    # ------------------------------------------------------------
    st.subheader("Matches per Month (Calendar Order)")

    if {"tourney_month_num", "tourney_month_name"}.issubset(df.columns):

        # EXACT STRUCTURE YOU REQUESTED:
        monthly = (
            df.groupby(["tourney_month_num", "tourney_month_name"])
              .size()
              .reset_index(name="count")
        )
        monthly = monthly.sort_values("tourney_month_num")

        fig = px.bar(
            monthly,
            x="tourney_month_name",
            y="count",
            title="Matches per Month (Ordered Jan → Dec)",
            color_discrete_sequence=[NEUTRAL]
        )
        st.plotly_chart(fig, use_container_width=True)

    else:
        # FALLBACK (alphabetical)
        vc_month = tidy_vc(df, "tourney_month_name")
        if vc_month is not None:
            fig = px.bar(
                vc_month,
                x="tourney_month_name",
                y="count",
                title="Matches per Month",
                color_discrete_sequence=[NEUTRAL]
            )
            st.plotly_chart(fig, use_container_width=True)

    # ------------------------------------------------------------
    # Draw Size Distribution — Curve + Bar (Correct Categories)
    # ------------------------------------------------------------
    if "draw_size" in df.columns:
        st.subheader("Draw Size Distribution (Correct Tournament Categories)")

        ds = df["draw_size"].value_counts().reset_index()
        ds.columns = ["draw_size", "count"]
        ds = ds.sort_values("draw_size")

        # Curve chart
        fig_curve = px.line(
            ds,
            x="draw_size",
            y="count",
            markers=True,
            title="Draw Size Curve (8, 16, 28, 32, 64, 128...)",
            color_discrete_sequence=[NEUTRAL]
        )
        fig_curve.update_layout(
            xaxis_title="Draw Size",
            yaxis_title="Number of Matches",
            showlegend=False
        )
        st.plotly_chart(fig_curve, use_container_width=True)

# ======================================================================
# WINNER DETAILS
# ======================================================================
elif section == "Winner Details":
    st.title("🏆 Winner Details")

    # Top winners
    wc = tidy_vc(df, "winner_name", top=20)
    if wc is not None:
        st.subheader("Top 20 Match Winners")
        fig = px.bar(
            wc, x="winner_name", y="count",
            color_discrete_sequence=[WIN_COLOR],
            title="Top 20 Winners"
        )
        st.plotly_chart(fig, use_container_width=True)

    # Winner country (IOC)
    w_ioc = tidy_vc(df, "winner_ioc")
    if w_ioc is not None:
        st.subheader("Winner Country Distribution (IOC Codes)")
        fig = px.bar(
            w_ioc.head(20),
            x="winner_ioc",
            y="count",
            title="Top 20 Winner Countries",
            color_discrete_sequence=[WIN_COLOR]
        )
        st.plotly_chart(fig, use_container_width=True)

    # Winner numeric summary
    w_nums = [c for c in ["winner_age", "winner_ht", "winner_rank"] if c in df]
    if w_nums:
        st.subheader("Winner Numeric Summary")
        st.dataframe(numeric_summary(df, w_nums))

    # Winner hand distribution
    wh = tidy_vc(df, "winner_hand")
    if wh is not None:
        st.subheader("Winner Hand Distribution")
        fig = px.pie(
            wh,
            names="winner_hand",
            values="count",
            title="Winner Hand",
            color_discrete_sequence=[WIN_COLOR, NEUTRAL]
        )
        st.plotly_chart(fig, use_container_width=True)

# ======================================================================
# LOSER DETAILS
# ======================================================================
elif section == "Loser Details":
    st.title("📉 Loser Details")

    # Top losers
    lc = tidy_vc(df, "loser_name", top=20)
    if lc is not None:
        st.subheader("Top 20 Match Losers")
        fig = px.bar(
            lc, x="loser_name", y="count",
            title="Top 20 Losers",
            color_discrete_sequence=[LOS_COLOR]
        )
        st.plotly_chart(fig, use_container_width=True)

    # Loser country (IOC)
    l_ioc = tidy_vc(df, "loser_ioc")
    if l_ioc is not None:
        st.subheader("Loser Country Distribution (IOC Codes)")
        fig = px.bar(
            l_ioc.head(20),
            x="loser_ioc",
            y="count",
            title="Top 20 Loser Countries",
            color_discrete_sequence=[LOS_COLOR]
        )
        st.plotly_chart(fig, use_container_width=True)

    # Loser numeric summary
    l_nums = [c for c in ["loser_age", "loser_ht", "loser_rank"] if c in df]
    if l_nums:
        st.subheader("Loser Numeric Summary")
        st.dataframe(numeric_summary(df, l_nums))

    # Loser hand distribution
    lh = tidy_vc(df, "loser_hand")
    if lh is not None:
        st.subheader("Loser Hand Distribution")
        fig = px.pie(
            lh,
            names="loser_hand",
            values="count",
            title="Loser Hand",
            color_discrete_sequence=[LOS_COLOR, NEUTRAL]
        )
        st.plotly_chart(fig, use_container_width=True)

# ======================================================================
# MATCH DETAILS
# ======================================================================
elif section == "Match Details":
    st.title("⏱ Match Details")

    if "minutes" in df.columns:
        st.subheader("Match Duration Distribution")
        fig = px.histogram(df, x="minutes", nbins=50,
                           color_discrete_sequence=[NEUTRAL])
        st.plotly_chart(fig, use_container_width=True)

        col = st.columns(2)
        col[0].metric("Average minutes", round(df["minutes"].mean(), 2))
        col[1].metric("Median minutes", round(df["minutes"].median(), 2))

    if "sets_num" in df.columns:
        st.subheader("Sets per Match")
        fig = px.histogram(df, x="sets_num", nbins=10,
                           color_discrete_sequence=[NEUTRAL])
        st.plotly_chart(fig, use_container_width=True)

    # FIXED SCORE TABLE
    if "score" in df.columns:
        st.subheader("Most Common Scores")
        score_df = df["score"].value_counts().reset_index()
        score_df.columns = ["score_value", "score_count"]
        st.dataframe(score_df.head(20))

    if "round" in df.columns:
        st.subheader("Round Distribution")
        rd = tidy_vc(df, "round")
        fig = px.bar(rd, x="round", y="count",
                     color_discrete_sequence=[NEUTRAL])
        st.plotly_chart(fig, use_container_width=True)


# ======================================================================
# WINNER MATCH STATISTICS
# ======================================================================
elif section == "Winner Match Statistics":
    st.title("📊 Winner Match Statistics")

    w_stats = [c for c in ["w_ace","w_df","w_svpt","w_1stIn","w_1stWon"] if c in df]
    if w_stats:
        st.subheader("Winner Stats Summary")
        st.dataframe(numeric_summary(df, w_stats))

    for c in w_stats:
        fig = px.histogram(df, x=c, nbins=40,
                           color_discrete_sequence=[WIN_COLOR],
                           title=f"{c} Distribution")
        st.plotly_chart(fig, use_container_width=True)


# ======================================================================
# LOSER MATCH STATISTICS
# ======================================================================
elif section == "Loser Match Statistics":
    st.title("📊 Loser Match Statistics")

    l_stats = [c for c in ["l_ace","l_df","l_svpt","l_1stIn","l_1stWon"] if c in df]
    if l_stats:
        st.subheader("Loser Stats Summary")
        st.dataframe(numeric_summary(df, l_stats))

    for c in l_stats:
        fig = px.histogram(df, x=c, nbins=40,
                           color_discrete_sequence=[LOS_COLOR],
                           title=f"{c} Distribution")
        st.plotly_chart(fig, use_container_width=True)
# Out:
# Overwriting /Users/klaymouna/Documents/CDSP/projects/final_project/app.py

# %%
! streamlit run /Users/klaymouna/Documents/CDSP/projects/final_project/app.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.1.148:8501
#
#   For better performance, install the Watchdog module:
#
#   $ xcode-select --install
#   $ pip install watchdog
#
# 2025-11-26 17:59:27.662 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# ^C
